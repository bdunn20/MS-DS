# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ![CleanShot 2022-05-17 at 08.50.31.png](attachment:08193459-ceda-455a-89e1-afbefb793923.png)

# %% [markdown]
# ![CleanShot 2022-05-17 at 08.58.38.png](attachment:31a36fec-7c79-46d9-a4fc-3e496d842b83.png)

# %% [markdown]
# ![CleanShot 2022-05-17 at 08.59.00.png](attachment:e12b7d5c-0ded-4a49-9829-a5965d853d40.png)

# %% [markdown]
# ![CleanShot 2022-05-17 at 09.19.51.png](attachment:0276994e-4cc5-49e7-9dd9-7c0c5193a9f4.png)

# %%
# define the vectors for size, topping and order
size = c("S", "M", "L")
topping = c("pepperoni", "meatball", "sausage", "extra cheese")
order = c("deliver", "pickup")

# keep track of the pizzas
pizzas = character(0)

# iterate over each value for each variable
for(i in 1:length(size)){
    for(j in 1: length(topping)){
        for(k in 1:length(order)){
        
            #create a pizza
            pizzas = rbind(pizzas, c(size[i], topping[j], order[k]))
        }
    }
}

# print out all of the pizzas; should have 24
pizzas

# %%
# count total number of large sausages; should get 2
#  we divide by 3 b/c rows are length 3, and we want
#   to convert back to number of rows (i.e., number of pizzas)
length(pizzas[pizzas[ ,1] == "L" & pizzas[ ,2] == "sausage"])/3

# %% [markdown]
# ![CleanShot 2022-05-17 at 09.23.22.png](attachment:b1ee34af-a064-472b-a81d-fadaa712fb99.png)

# %%
# generate all of the possible permutations of the letters
#  A-G
perms = combinat::permn(c("A", "B", "C", "D", "E", "F", "G"))

# look at the first few permutations
head(perms)

# %%
# should get factorial(7) = 5040
length(perms)

# %% [markdown]
# ![CleanShot 2022-05-17 at 09.47.02.png](attachment:5cf001b7-0062-41bc-8b3e-caac5767a134.png)

# %%
# generate the committees (people labeled 1 to 5)
# this is 5 choose three example
committees = gtools::combinations(n = 5, r = 3)

# should get choose (5,3) = factorial(5) / (factorial(3)*factorial(2)) = 10 committees
committees

# %% [markdown]
# ![CleanShot 2022-05-17 at 09.52.51.png](attachment:5167a0f1-077e-4c72-a757-35f99ee095a9.png)

# %% [markdown]
# ![CleanShot 2022-05-17 at 14.11.25.png](attachment:d49d8d05-d9ab-4dfe-b538-431c912b4d96.png)

# %% [markdown]
# ![CleanShot 2022-05-17 at 14.15.31.png](attachment:2b58eaf9-10b6-4057-b71f-5f07d33f4ce3.png)

# %%
# a
10^4

# b (order matters. w/o replacement)
# n!/(n-k)!
